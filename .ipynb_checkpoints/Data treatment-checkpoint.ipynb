# %%
import pandas as pd

# %%
data_big = pd.read_csv('./data/df_height_beforemainnet.csv', index_col=[0])

# %%
data_big
# Out:
#         height  network_height  new_baseline_power  raw_bytes_network_power  \
# 0          239               1         1024.255806                 0.046875
# 1          240               1         1024.256877                 0.046875
# 2          241               1         1024.257947                 0.046875
# 3          242               1         1024.259018                 0.046875
# 4          243               1         1024.260088                 0.046875
# ...        ...             ...                 ...                      ...
# 146017  148884           15409         2830.520955               569.074677
# 146018  148885           15409         2830.522822               569.074677
# 146019  148886           15409         2830.524688               569.146362
# 146020  148887           15409         2830.526554               569.146362
# 146021  148888           15410         2830.528421               569.146362
#
# ...
