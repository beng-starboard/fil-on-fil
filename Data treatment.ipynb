# %%
import pandas as pd

# %%
data_small = pd.read_csv('./data/df_height_beforemainnet.csv', index_col=[0])
data_big = pd.read_csv('./data/df_height.csv', index_col=[0])

# %%
pd.concat([data_small,data_big]).reset_index().to_csv('./data/df_height_full.csv')

# %%
del data_small, data_big

# %%
dd = pd.read_csv('./data/df_height_full.csv')
dda = pd.read_csv('./data/df_height_beforemainnet.csv')

# %%
dd.iloc[len(dda)-20:len(dda)+20]
# Out:
#         Unnamed: 0   index  height  network_height  new_baseline_power  \
# 146002      146002  146002  148869           15405         2830.492959
# 146003      146003  146003  148870           15406         2830.494826
# 146004      146004  146004  148871           15406         2830.496692
# 146005      146005  146005  148872           15406         2830.498558
# 146006      146006  146006  148873           15406         2830.500425
# 146007      146007  146007  148874           15406         2830.502291
# 146008      146008  146008  148875           15407         2830.504158
# 146009      146009  146009  148876           15407         2830.506024
# 146010      146010  146010  148877           15407         2830.507890
# 146011      146011  146011  148878           15407         2830.509757
# 146012      146012  146012  148879           15408         2830.511623
# 146013      146013  146013  148880           15408         2830.513490
# ...
